# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Baseline Model

# %%
# bring in data
path = '/Users/reneehall/Documents/Learning/lighthouse_labs/coursework-lighthouse-labs/Mid-term project/colab_data/'
fl_df = pd.read_csv(path+'cleaned_flights_sample.csv')

# %%
# remove columns that we can't predict ahead of time, including departure delay
to_drop = ['cancellation_code', 'carrier_delay', 'weather_delay', 'nas_delay','security_delay','late_aircraft_delay','first_dep_time','total_add_gtime','longest_add_gtime', 'dep_delay', 'cancelled']
fl_df = fl_df.drop(labels=to_drop, axis=1)

# %%
fl_df.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-10-26                 UA                 WN          WN
# 1  2018-03-26                 DL                 UA          UA
# 2  2019-02-06                 WN                 NK          NK
# 3  2019-11-11                 DL                 DL          DL
# 4  2019-03-25                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                4052                EV   N8541W               2542
# 1                2733                DL   N938FR                351
# 2                5531                OO   N367CA               6266
# 3                 629                B6   N907WN               4607
# 4                 296                HA   N434YX               4535
#
#    origin_airport_id origin  ... arr_time  arr_delay cancelled diverted  dup  \
# 0              12954    LGB  ...   1650.0      -16.0       0.0      0.0    N
# 1              13930    ORD  ...   1207.0      -19.0       0.0      0.0    N
# 2              10868    CAE  ...   1853.0       14.0       0.0      0.0    N
# 3              14869    SLC  ...    613.0       -7.0       0.0      0.0    N
# 4              14771    SFO  ...   1138.0       25.0       0.0      0.0    N
#
#    crs_elapsed_time  actual_elapsed_time  air_time  flights  distance
# 0              84.0                 90.0      67.0      1.0     528.0
# 1             215.0                148.0     116.0      1.0     404.0
# 2             114.0                 81.0      67.0      1.0      93.0
# 3             188.0                207.0     186.0      1.0     315.0
# 4              70.0                118.0      92.0      1.0     388.0
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Data transformation

# %%
# before linear regression, need to transform categorical into continuous

# date string to unix
import datetime as dt 

fl_df['fl_date'] = pd.to_datetime(fl_df['fl_date'])
fl_df['timestamp'] = fl_df['fl_date'].map(dt.datetime.toordinal)
fl_df = fl_df.drop(labels=['fl_date'], axis=1)

# %%
# encode categorical vars
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

cat_vars = fl_df.select_dtypes(include= 'object').columns.tolist()
for col in cat_vars:
    fl_df[col] = label_encoder.fit_transform(fl_df[col])

# %%
fl_df.head()
# Out:
#    mkt_unique_carrier  branded_code_share  mkt_carrier  mkt_carrier_fl_num  \
# 0                   0                  15           10                4052
# 1                   0                  12            8                2733
# 2                   0                  11            7                5531
# 3                   0                   5            3                 629
# 4                   0                  15           10                 296
#
#    op_unique_carrier  tail_num  op_carrier_fl_num  origin_airport_id  origin  \
# 0                 10      4925               2542              12954     206
# 1                  8      5882                351              13930     257
# 2                 19      1818               6266              10868      61
# 3                  5      5499               4607              14869     332
# 4                 14      2264               4535              14771     323
#
#    origin_city_name  ...  arr_delay  cancelled  diverted  dup  \
# 0               283  ...      -16.0        0.0       0.0    0
# 1               314  ...      -19.0        0.0       0.0    0
# 2               298  ...       14.0        0.0       0.0    0
# 3                17  ...       -7.0        0.0       0.0    0
# 4               247  ...       25.0        0.0       0.0    0
#
#    crs_elapsed_time  actual_elapsed_time  air_time  flights  distance  \
# 0              84.0                 90.0      67.0      1.0     528.0
# 1             215.0                148.0     116.0      1.0     404.0
# 2             114.0                 81.0      67.0      1.0      93.0
# 3             188.0                207.0     186.0      1.0     315.0
# 4              70.0                118.0      92.0      1.0     388.0
#
#    timestamp
# 0     736993
# 1     736779
# 2     737096
# 3     737374
# 4     737143
#
# [5 rows x 31 columns]

# %%
# separate x and y
X = fl_df.drop(labels='arr_delay', axis=1)
y = fl_df['arr_delay']

# %%
# make train-test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=101)

# %%
# predict using linear regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
y_lr = lr.predict(X_test)

# %%
# evaluate using MAE
from sklearn.metrics import mean_absolute_error

MAE = mean_absolute_error(y_test, y_lr)
print(MAE)
# Out:
# 24.193434801214913

# %%
# evaluate using R2
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_lr)
print(R2)
# Out:
# 0.0009193898643401477

# %%
# evaluate with adjusted R2
adj_R2 = 1 - ((1 - R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print(adj_R2)
# Out:
# 0.0007584000455150841

# %%
# calculate MAPE
from sklearn.metrics import mean_absolute_percentage_error

MAPE = mean_absolute_percentage_error(y_test,y_lr)
print(MAPE)
# Out:
# 452536682485260.2

# %% [markdown]
# ## Baseline Scaled X

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

Xsc = scaler.fit_transform(X)

# %%
# make train-test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=101)

# predict using linear regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
y_lr = lr.predict(X_test)

# evaluate using MAE
MAE = mean_absolute_error(y_test, y_lr)
print(f"MAE: {MAE}")

# evaluate using R2
R2 = r2_score(y_test, y_lr)
print(f"R2: {R2}")

# evaluate with adjusted R2
adj_R2 = 1 - ((1 - R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print(f"adj_R2: {adj_R2}")

# calculate MAPE
MAPE = mean_absolute_percentage_error(y_test,y_lr)
print(f"MAPE: {MAPE}")
# Out:
# MAE: 24.193434801214913
# R2: 0.0009193898643401477
# adj_R2: 0.0007584000455150841
# MAPE: 452536682485260.2

# %% [markdown]
# # Remove Features

# %%
# Out:
#    mkt_unique_carrier  branded_code_share  mkt_carrier  mkt_carrier_fl_num  \
# 0                   8                  15           10                4052
# 1                   3                  12            8                2733
# 2                  10                  11            7                5531
# 3                   3                   5            3                 629
# 4                  10                  15           10                 296
#
#    op_unique_carrier  tail_num  op_carrier_fl_num  origin_airport_id  origin  \
# 0                 10      4925               2542              12954     206
# 1                  8      5882                351              13930     257
# 2                 19      1818               6266              10868      61
# 3                  5      5499               4607              14869     332
# 4                 14      2264               4535              14771     323
#
#    origin_city_name  ...  crs_arr_time  arr_time  diverted  dup  \
# 0               283  ...          1955    1650.0       0.0    0
# 1               314  ...          1724    1207.0       0.0    0
# 2               298  ...           920    1853.0       0.0    0
# 3                17  ...          1809     613.0       0.0    0
# 4               247  ...          1425    1138.0       0.0    0
#
#    crs_elapsed_time  actual_elapsed_time  air_time  flights  distance  \
# 0              84.0                 90.0      67.0      1.0     528.0
# 1             215.0                148.0     116.0      1.0     404.0
# 2             114.0                 81.0      67.0      1.0      93.0
# 3             188.0                207.0     186.0      1.0     315.0
# 4              70.0                118.0      92.0      1.0     388.0
#
#    timestamp
# 0     736993
# 1     736779
# 2     737096
# 3     737374
# 4     737143
#
# [5 rows x 29 columns]
