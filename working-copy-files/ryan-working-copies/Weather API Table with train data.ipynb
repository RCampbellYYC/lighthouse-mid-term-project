# %% [markdown]
# # World Weather API Notebook
# - Pulls Weather Data
# - Bins data into
#     - sunny
#     - cloudy
#     - rainy
#     - snow
# - Adds Weather Data to Flights Table

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt

# %%
flights = pd.read_csv(r'C:\Users\Ryan\Lighthouse\Bootcamp\w6\midterm\Data\cleaned\cleaned_flights_sample.csv', delimiter=',', low_memory=False)
flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-10-26                 UA                 WN          WN
# 1  2018-03-26                 DL                 UA          UA
# 2  2019-02-06                 WN                 NK          NK
# 3  2019-11-11                 DL                 DL          DL
# 4  2019-03-25                 WN                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                4052                EV   N8541W               2542
# 1                2733                DL   N938FR                351
# 2                5531                OO   N367CA               6266
# 3                 629                B6   N907WN               4607
# 4                 296                HA   N434YX               4535
#
#    origin_airport_id origin  ... flights  distance carrier_delay  \
# 0              12954    LGB  ...     1.0     528.0           NaN
# 1              13930    ORD  ...     1.0     404.0           NaN
# 2              10868    CAE  ...     1.0      93.0          40.0
# 3              14869    SLC  ...     1.0     315.0           NaN
# 4              14771    SFO  ...     1.0     388.0           NaN
#
#   weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 0           NaN        NaN             NaN                  NaN
# 1           NaN       18.0             0.0                  0.0
# 2           0.0        NaN             NaN                  0.0
# 3           NaN       20.0             0.0                  NaN
# 4           NaN        NaN             NaN                  NaN
#
#    first_dep_time  total_add_gtime  longest_add_gtime
# 0             NaN              NaN                NaN
# 1             NaN              NaN                NaN
# 2             NaN              NaN                NaN
# 3             NaN              NaN                NaN
# 4             NaN              NaN                NaN
#
# [5 rows x 41 columns]

# %%
#Convert fl_date to a date
import time
import datetime
flights['fl_date'] = pd.to_datetime(flights['fl_date']).dt.strftime('%Y-%m-%d')

# %%
# DO NOT RUN THIS BLOCK - IT PULLS ALL THE WEATHER DATA - IT TAKES A LONG TIME
# I ALREADY PULLED THE CSVS!!!
#Get Weather Data from World Weather API
from wwo_hist import retrieve_hist_data
frequency=24
start_date = '01-JAN-2018'
end_date = '31-DEC-2019'
api_key = 'd385b2b23e2c4b2392535423211101'
location_list = ['ORD', 'ATL', 'DFW', 'DEN', 'LAX', 'CLT', 'SEA', 'SFO', 'PHX', 'LGA']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)

# %%
# Import weather data for top 10 airports with weather delays by count
import glob

path = r'C:\Users\Ryan\Lighthouse\Bootcamp\w6\midterm\Weather\csv'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

weather = pd.concat(li, axis=0, ignore_index=True)

# %%
#Convert to date and filter table
weather['date_time'] = pd.to_datetime(weather['date_time']).dt.date
weather = weather.filter(['date_time', 'location', 'totalSnow_cm', 'sunHour', 'cloudcover', 'precipMM'])

# %%
# Convert date column to date
weather['date_time'] = pd.to_datetime(weather['date_time']).dt.strftime('%Y-%m-%d')

# %%
# Add weather_type to table
weather_type = []
for i in range(len(weather)):
    if weather.iloc[i]['totalSnow_cm'] > 0:
        weather_type.append('Snowy')
    elif weather.iloc[i]['precipMM'] > 0:
        weather_type.append('Rainy')
    elif weather.iloc[i]['cloudcover'] > 50:
        weather_type.append('Cloudy')
    else:
        weather_type.append('Sunny')
weather['weather_type'] = weather_type

# %%
weather.head()
# Out:
#     date_time location  totalSnow_cm  sunHour  cloudcover  precipMM  \
# 0  2018-01-01      ABE           0.0      6.9          30       0.0
# 1  2018-01-02      ABE           0.0      8.7          27       0.0
# 2  2018-01-03      ABE           0.0      7.0          58       0.0
# 3  2018-01-04      ABE           0.2      3.5          99       4.7
# 4  2018-01-05      ABE           0.0      5.2          71       0.0
#
#   weather_type
# 0        Sunny
# 1        Sunny
# 2       Cloudy
# 3        Snowy
# 4       Cloudy

# %%
#Merge flights and weather tables
flights_weather = pd.merge(flights, weather, how='left', left_on=['fl_date', 'dest'], right_on = ['date_time', 'location'])

# %%
flights_weather
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2018-10-26                 UA                 WN          WN
# 1       2018-03-26                 DL                 UA          UA
# 2       2019-02-06                 WN                 NK          NK
# 3       2019-11-11                 DL                 DL          DL
# 4       2019-03-25                 WN                 WN          WN
# ...            ...                ...                ...         ...
# 599995  2018-01-28                 DL                 DL          DL
# 599996  2019-04-24                 AA                 AS          AS
# 599997  2018-09-03                 WN       AA_CODESHARE          AA
# 599998  2018-04-18                 AS                 UA          UA
# 599999  2019-05-19                 HA       AA_CODESHARE          AA
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                     4052                EV   N8541W               2542
# 1                     2733                DL   N938FR                351
# 2                     5531                OO   N367CA               6266
# 3                      629                B6   N907WN               4607
# 4                      296                HA   N434YX               4535
# ...                    ...               ...      ...                ...
# 599995                1140                AA   N200NV                295
# 599996                3827                WN   N562JB                181
# 599997                1570                AA   N7863A               4858
# 599998                5390                9E   N509JB                494
# 599999                5494                OH   N669AW               1643
#
#         origin_airport_id origin  ... first_dep_time  total_add_gtime  \
# 0                   12954    LGB  ...            NaN              NaN
# 1                   13930    ORD  ...            NaN              NaN
# 2                   10868    CAE  ...            NaN              NaN
# 3                   14869    SLC  ...            NaN              NaN
# 4                   14771    SFO  ...            NaN              NaN
# ...                   ...    ...  ...            ...              ...
# 599995              13930    ORD  ...            NaN              NaN
# 599996              14893    SMF  ...            NaN              NaN
# 599997              12278    ICT  ...            NaN              NaN
# 599998              14100    PHL  ...            NaN              NaN
# 599999              14747    SEA  ...            NaN              NaN
#
#        longest_add_gtime   date_time  location  totalSnow_cm  sunHour  \
# 0                    NaN  2018-10-26       MCO           0.0      8.7
# 1                    NaN  2018-03-26       ASE           0.0     11.6
# 2                    NaN  2019-02-06       PHX           0.0     10.8
# 3                    NaN  2019-11-11       TUL           0.2      4.0
# 4                    NaN  2019-03-25       DCA           0.0      7.5
# ...                  ...         ...       ...           ...      ...
# 599995               NaN  2018-01-28       ITO           0.0     11.5
# 599996               NaN  2019-04-24       DFW           0.0      8.5
# 599997               NaN  2018-09-03       IAH           0.0     12.4
# 599998               NaN  2018-04-18       FAI           0.0     14.5
# 599999               NaN  2019-05-19       LAS           0.0     13.4
#
#         cloudcover  precipMM  weather_type
# 0             35.0       0.0         Sunny
# 1              9.0       0.0         Sunny
# 2             23.0       1.9         Rainy
# 3             87.0       5.5         Snowy
# 4             72.0       0.5         Rainy
# ...            ...       ...           ...
# 599995        30.0       3.1         Rainy
# 599996        88.0      67.8         Rainy
# 599997        52.0       7.9         Rainy
# 599998         6.0       0.0         Sunny
# 599999        23.0       0.4         Rainy
#
# [600000 rows x 48 columns]

# %%
#Check how many rows of weather data we have
flights_weather['weather_type'].value_counts()
# Out:
# Rainy     284204
# Sunny     261744
# Cloudy     28689
# Snowy      25351
# Name: weather_type, dtype: int64

# %%
#Check for nan
# NICE!! We have pretty much all the data!! Only 15 nan
flights_weather['weather_type'].isna().sum()
# Out:
# 12

# %%
# Export Weather table to csv
weather.to_csv("weather_table.csv", sep = ",")

# %%
# Export flights table combiend with weather table to csv
flights_weather.to_csv("flights_weather_table.csv", sep = ",")
